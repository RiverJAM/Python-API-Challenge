# %%
# Dependencies
import matplotlib.pyplot as plt
import requests
from scipy import stats
import pandas as pd
from config import api_key
from citipy import citipy
import numpy as np
import random

# %%
#output_data_file = "output_data/cities.csv"

# %%
#How to get Random Cities? (Randomly select at least 500 unique (non-repeat) cities based on latitude and longitude.)
#500 random latitude and longitudes
Lats = np.random.uniform(-60,75,970)
Longs = np.random.uniform(-160,175,970)
coor = list(zip(Lats, Longs))

# %%
cities=[]
for x in coor[0:]:
    print(x)
    city = citipy.nearest_city(x[0],x[1]).city_name
    if city not in cities:
        cities.append(city)
# Out:
# (46.34582433019753, 111.41755482716337)
# (39.7590446836697, 60.669195963151424)
# (15.628666709494652, 41.37342205078514)
# (-28.936636484605092, -135.79150792846528)
# (-54.42794758272611, -47.060363210465056)
# (37.28984735316391, 165.8116817247889)
# (-47.41355951495472, 70.46215676109543)
# (34.60347011624246, -16.74177903663582)
# (16.276679176130955, -42.84553536362799)
# (65.18659259315692, 135.32337860478185)
# (15.827709517197775, 48.6436572501884)
# (45.562617905349924, 19.546834767555936)
# (17.577950967900662, -124.73431355490521)
# (38.71023764600065, -154.39903491262567)
# (24.32254285421554, 18.248026537826632)
# (11.089452988129352, 167.48000812297914)
# (-32.982658672260385, -51.656993372507785)
# (-54.24800207143548, 32.10689766444901)
# (-12.603396800725953, -36.06908194967038)
# (50.92856655190235, -30.27197131343337)
# (-46.72711189744011, -138.16173124370007)
# (-14.22158463841398, 130.58156223850057)
# (-45.642475322585405, -142.4710414136231)
# (71.95521030872234, -105.63509882627453)
# (-3.052656049012427, -55.00772597136874)
# (-20.54730041189461, -6.1723969078455525)
# (17.342687294111798, -135.25943974015738)
# (-31.5462753517488, 19.55722197743279)
# (16.61106797554183, -67.71638577414913)
# (6.735516761903085, 94.7334004197204)
# (25.47414424448631, -100.632761235256)
# (-1.9988524470273745, 131.48146503604306)
# (-30.37755745157803, 173.5164191646116)
# (-45.0005229503374, -43.67877245628182)
# (-48.708620203835615, 144.68122187996124)
# (-25.754475457227784, 5.7091918841925064)
# (34.81028907325981, 153.84069266913673)
# (-29.800363833839047, 141.0396283685962)
# (58.52377469521295, 13.3342970963636)
# (67.09247041315992, 102.96233383414818)
# (42.51510895289306, -76.35851636430493)
# (-43.313547471552496, 17.386456700733618)
# (-10.657445195220312, -109.2397011298064)
# (-57.31639390934659, -93.24443481203089)
# (14.012365707243205, -22.37549634210677)
# (-35.372629303892076, 81.51464624278069)
# (-26.473158982500422, -38.67629068969167)
# (39.596552813098484, -56.979138872496634)
# (26.13300204849513, -61.44596788402417)
# (-55.8915891327106, -82.73882121782106)
# (69.62172924602208, 152.51459385543365)
# (37.73348725829577, 19.193947908280194)
# (8.694094417365932, -34.301176696632666)
# (-1.2825905857858473, -140.37734771479597)
# (56.04003447233707, -147.44580714683352)
# (73.32945869712671, -96.50170732781521)
# (63.280723382445714, -116.74971566638906)
# (39.447689272170834, 32.19532263902536)
# (14.510160458267833, -37.721482876769656)
# (15.787918565358424, -98.16831769017529)
# (16.045761879935327, -19.070436895280267)

#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 11.37,
#   'feels_like': 9.04,
#   'temp_min': 11.37,
#   'temp_max': 11.37,
#   'pressure': 1020,
#   'humidity': 38,
#   'sea_level': 1020,
#   'grnd_level': 892},
#  'visibility': 10000,
#  'wind': {'speed': 0.02, 'deg': 149},
#  'clouds': {'all': 0},
#  'dt': 1602622578,
#  'sys': {'country': 'IR', 'sunrise': 1602642712, 'sunset': 1602683550},
#  'timezone': 12600,
#  'id': 116402,
#  'name': 'Semnan',
#  'cod': 200}

# %%
#build a dataframe to store data
#Divide Latitudes into N/S
#df to partition
#make dictionary
Weather_dict = {
    "City": cities ,
    "Latitude": "" ,
    "Temperature" : "",
    "Humidity": "",
    "Clouds %" : "",
    "Wind Speed (mph)": ""
    
}
Weat = pd.DataFrame(Weather_dict)
Weat
# Out:
#               City Latitude Temperature Humidity Clouds % Wind Speed (mph)
# 0        ondorhaan
# 1          druzhba
# 2            jizan
# 3          rikitea
# 4    mar del plata
# ..             ...      ...         ...      ...      ...              ...
# 536         roblin
# 537      ulladulla
# 538         contai
# 539        bontang
# 540      ambikapur
#
# [541 rows x 6 columns]

# %%
# set up lists to hold reponse info
lat = []
temp = []
hum = []
clouds = []
winds = []

citynumber = 0
# Ref: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.iterrows.html
# Loop through the list of cities and perform a request for data on each
for index, row in Weat.iterrows():
    city = row['City']
    response = requests.get(query_url + city).json()
    
    try:
        Weat.loc[index, "Latitude"] = response['coord']['lat']
        Weat.loc[index, "Temperature"] = response['main']['temp']
        Weat.loc[index, "Humidity"] = response['main']['humidity']
        Weat.loc[index, "Clouds %"] = response['clouds']['all']
        Weat.loc[index, "Wind Speed (mph)"] = response['wind']['speed']
        citynumber += 1
        
#         hum.append(response['main']['humidity'])
#         clouds.append(response['clouds']['all'])
#         winds.append(response['wind']['speed'])
        
 
      
        
    # Handle exceptions 
    except:
        # Append null values
        print("City not found")
        #continue?
        continue
# Out:
# City not found
# City not found
# City not found
# City not found
# City not found
# City not found
# City not found
# City not found
# City not found
# City not found
# City not found
# City not found
# City not found
# City not found
# City not found
# City not found
# City not found
# City not found
# City not found
# City not found
# City not found
# City not found
# City not found
# City not found
# City not found
# City not found
# City not found
# City not found
# City not found
# City not found
# City not found
# City not found
# City not found
# City not found
# City not found
# City not found
# City not found
# City not found
# City not found
# City not found
# City not found

# %%
Weat
# Out:
#               City Latitude Temperature Humidity Clouds % Wind Speed (mph)
# 0        ondorhaan
# 1          druzhba    52.04       13.56       83        0             4.34
# 2            jizan    17.33          31       66        0              1.5
# 3          rikitea   -23.12       22.79       74        0             6.22
# 4    mar del plata      -38       15.36       67        0              5.7
# ..             ...      ...         ...      ...      ...              ...
# 536         roblin    51.23         8.3       50        0            10.26
# 537      ulladulla   -35.35       13.37      100       90              3.6
# 538         contai    21.78       26.84       89       33             3.65
# 539        bontang     0.13       26.19       83       97             1.29
# 540      ambikapur    23.12       21.52       90      100             1.68
#
# [541 rows x 6 columns]

# %%
Weat['Temperature'] = pd.to_numeric(Weat['Temperature'])

#stole this function from here
## http://ucsdlib.github.io/win2016-python-gps/functions-pandas.html
def C_to_F(temp_celsius):
    temp_fahr = (temp_celsius *9/5)+32 
    return  temp_fahr

Weat["Temperature_F"] = C_to_F(Weat["Temperature"])

# %%
#put whole df into csv
Weat.to_csv('..\Weather_df.csv')

# %%
## Convert to floats and store Poverty Rate and Bank Count as x and y values

Weat['Latitude'] = pd.to_numeric(Weat['Latitude'])

lat = Weat['Latitude']
temp = Weat['Temperature_F']

# Run linear regression
# (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
# regress_values = x_values * slope + intercept
# line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(lat,temp)

# Plot regression line
# plt.plot(x_values,regress_values,"r-")
# plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Temperature (Centigrade)')

# Print r square value
# print(f"R squared: {rvalue**2}")

# Show plot
plt.show()
plt.savefig("../GlobalTemperatureVLatitude.png")

# %% [markdown]
# # Temperature vs Latitude:
# It appears the temperature goes up as you approach the equator from both the north and the south.

# %%
# Plot scatter plot
Weat['Humidity'] = pd.to_numeric(Weat['Humidity'])
hum = Weat['Humidity']
plt.scatter(lat,hum)
# Label plot
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.savefig("../GlobalHumidityVLatitude.png")
# Out:
# Text(0, 0.5, 'Humidity')

# %% [markdown]
# ## Humidity vs Latitude
# There appears to be no relationship between humididty and latititude

# %%
# Plot scatter plot
Weat['Wind Speed (mph)'] = pd.to_numeric(Weat['Wind Speed (mph)'])
winds = Weat['Wind Speed (mph)']
plt.scatter(lat,winds)
# Label plot
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.savefig("../GlobalWindVLatitude.png")
# Out:
# Text(0, 0.5, 'Wind Speed (mph)')

# %% [markdown]
# # Wind Speed vs. Latitude
# The apears to be no relation between Wind Speed in mph and Latitude.

# %%
#change variable
Weat['Clouds %'] = pd.to_numeric(Weat['Clouds %'])
clouds = Weat['Clouds %']
# Plot scatter plot
plt.scatter(lat,clouds)
# Label plot
plt.xlabel('Latitude')
plt.ylabel('Clouds %')
plt.savefig("../GlobalCloudVLatitude.png")
# Out:
# Text(0, 0.5, 'Clouds %')

# %% [markdown]
# # Cloud & vs. Latitude
# It is not that there doesn't seem to be a pattern, but it does not seem to be a relationship between these two variables.

# %%
#Northern Hemisphere Data
Northern_df = Weat.loc[(Weat["Latitude"] >= 0)]
Northern_df
# Out:
#                City  Latitude  Temperature  Humidity  Clouds %  \
# 1           druzhba     52.04        13.56      83.0       0.0
# 2             jizan     17.33        31.00      66.0       0.0
# 5    severo-kurilsk     50.68        10.36      89.0     100.0
# 7           camacha     33.08        21.00      68.0      20.0
# 8           cayenne      4.93        30.00      66.0      76.0
# ..              ...       ...          ...       ...       ...
# 535         masindi      1.67        17.01      92.0      65.0
# 536          roblin     51.23         8.30      50.0       0.0
# 538          contai     21.78        26.84      89.0      33.0
# 539         bontang      0.13        26.19      83.0      97.0
# 540       ambikapur     23.12        21.52      90.0     100.0
#
#      Wind Speed (mph)  Temperature_F
# 1                4.34         56.408
# 2                1.50         87.800
# 5               12.96         50.648
# 7                3.10         69.800
# 8                5.10         86.000
# ..                ...            ...
# 535              0.19         62.618
# 536             10.26         46.940
# 538              3.65         80.312
# 539              1.29         79.142
# 540              1.68         70.736
#
# [350 rows x 7 columns]

# %%
## Convert variables
Northern_df['Temperature'] = pd.to_numeric(Northern_df['Temperature'])
Northern_df['Latitude'] = pd.to_numeric(Northern_df['Latitude'])

#List variables
lat = Northern_df['Latitude']
temp = Northern_df['Temperature']

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(lat, temp)
regress_values = lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(lat,temp)

# Plot regression line
plt.plot(lat,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Temperature')

# Print r square value
print(f"R squared: {rvalue**2}")

# Show plot
plt.show()
plt.savefig("../NorthernTempVLatitude.png")
# Out:
# R squared: 0.7114620364728891
# <ipython-input-19-4153acf64820>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Northern_df['Temperature'] = pd.to_numeric(Northern_df['Temperature'])
# <ipython-input-19-4153acf64820>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Northern_df['Latitude'] = pd.to_numeric(Northern_df['Latitude'])

# %% [markdown]
# # Northern Hemisphere  Temp v Latitude
# It gets warmer as you approach the equator. The R-squared gives us a strong correlation here.

# %%
#Southern Hemisphere Data
Southern_df = Weat.loc[(Weat["Latitude"] < 0)]
Southern_df
# Out:
#               City  Latitude  Temperature  Humidity  Clouds %  \
# 3          rikitea    -23.12        22.79      74.0       0.0
# 4    mar del plata    -38.00        15.36      67.0       0.0
# 6         souillac    -20.52        23.00      88.0      75.0
# 16      rio grande    -32.03        15.47      79.0      44.0
# 17     port alfred    -33.59        14.23      75.0       1.0
# ..             ...       ...          ...       ...       ...
# 508          bluff    -46.60         7.22      73.0      98.0
# 517      contamana     -7.33        32.36      44.0      75.0
# 520  alice springs    -23.70        12.00      54.0       0.0
# 532        labuhan     -6.88        25.78      82.0     100.0
# 537      ulladulla    -35.35        13.37     100.0      90.0
#
#      Wind Speed (mph)  Temperature_F
# 3                6.22         73.022
# 4                5.70         59.648
# 6                4.60         73.400
# 16               2.82         59.846
# 17               5.80         57.614
# ..                ...            ...
# 508              4.47         44.996
# 517              2.63         90.248
# 520              2.10         53.600
# 532              3.23         78.404
# 537              3.60         56.066
#
# [150 rows x 7 columns]

# %%
## Convert variables
Southern_df['Temperature'] = pd.to_numeric(Southern_df['Temperature'])
Southern_df['Latitude'] = pd.to_numeric(Southern_df['Latitude'])

#List variables
lat = Southern_df['Latitude']
temp = Southern_df['Temperature']

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(lat, temp)
regress_values = lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(lat,temp)

# Plot regression line
plt.plot(lat,regress_values,"r-")
plt.annotate(line_eq,(-30,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Temperature')

# Print r square value
print(f"R squared: {rvalue**2}")

# Show plot
plt.show()
plt.savefig("../SouthernTempVLatitude.png")
# Out:
# <ipython-input-31-bfffcfd5c7ad>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Southern_df['Temperature'] = pd.to_numeric(Southern_df['Temperature'])
# <ipython-input-31-bfffcfd5c7ad>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Southern_df['Latitude'] = pd.to_numeric(Southern_df['Latitude'])
# R squared: 0.5542064789002245

# %% [markdown]
# # Southern Hemisphere Temperature v Latitude
# It gets warmer as you approach the equator. This is the relationship we would expect. The R-squared gives us a medium strength correlation.

# %%
# Northern Hemisphere - Humidity (%) vs. Latitude
## Convert variables
Northern_df['Humidity'] = pd.to_numeric(Northern_df['Humidity'])

#List variables
lat = Northern_df['Latitude']
hum = Northern_df['Humidity']

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(lat, hum)
regress_values = lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(lat,hum)

# Plot regression line
plt.plot(lat,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Humidity')

# Print r square value
print(f"R squared: {rvalue**2}")

# Show plot
plt.show()
plt.savefig("../NorthernHumidityVLatitude.png")
# Out:
# <ipython-input-22-273a94b02e13>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Northern_df['Humidity'] = pd.to_numeric(Northern_df['Humidity'])
# R squared: 0.03502637934261489

# %% [markdown]
# # Humidity v Latitude in Northern Hemisphere
# This data doesn't appear to be linear and the low R-squared value supports that.

# %%
# Southern Hemisphere - Humidity (%) vs. Latitude
## Convert variables
Southern_df['Humidity'] = pd.to_numeric(Southern_df['Humidity'])



#List variables
lat = Southern_df['Latitude']
hum = Southern_df['Humidity']

mask = ~np.isnan(hum) & ~np.isnan(lat)
lat = lat[mask]
hum = hum[mask]
# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(lat, hum)
regress_values = lat * slope + intercept
line_eq1 = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(lat,hum)

# Plot regression line
plt.plot(lat,regress_values,"r-")
plt.annotate(line_eq1,(-30,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Humidity')

# Print r square value
print(f"R squared: {rvalue**2}")

# Show plot
plt.show()
plt.savefig("../SouthernHumidityVLatitude.png")
# Out:
# R squared: 0.03559490872144802
# <ipython-input-32-1a3b7f4bc311>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Southern_df['Humidity'] = pd.to_numeric(Southern_df['Humidity'])

# %% [markdown]
# # Southern Hemisphere Humidity v Latitude
# There does not appear to be a linear relationship.

# %%
#Northern Hemisphere - Cloudiness (%) vs. Latitude
## Convert variables
Northern_df['Clouds %'] = pd.to_numeric(Northern_df['Clouds %'])

#List variables
lat = Northern_df['Latitude']
clouds = Northern_df['Clouds %']

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(lat, clouds)
regress_values = lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(lat,clouds)

# Plot regression line
plt.plot(lat,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

# Print r square value
print(f"R squared: {rvalue**2}")

# Show plot
plt.show()
plt.savefig("../NorthernCloudVLatitude.png")
# Out:
# R squared: 0.030329030915210643
# <ipython-input-25-3780de4e7654>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Northern_df['Clouds %'] = pd.to_numeric(Northern_df['Clouds %'])

# %% [markdown]
# # Northern Hemisphere Cloudiness V Latitude
# There does not appear to be a linear relationship. There does seem to be certain groupings of cloudiness though.

# %%
#Southern Hemisphere - Cloudiness (%) vs. Latitude
## Convert variables
Southern_df['Clouds %'] = pd.to_numeric(Southern_df['Clouds %'])

#List variables
lat = Southern_df['Latitude']
clouds = Southern_df['Clouds %']

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(lat, clouds)
regress_values = lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(lat,clouds)

# Plot regression line
plt.plot(lat,regress_values,"r-")
plt.annotate(line_eq,(-30,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

# Print r square value
print(f"R squared: {rvalue**2}")

# Show plot
plt.show()
plt.savefig("../SouthernCloudVLatitude.png")
# Out:
# <ipython-input-33-74c6db3fcf4b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Southern_df['Clouds %'] = pd.to_numeric(Southern_df['Clouds %'])
# R squared: 0.05717230912950325

# %% [markdown]
# # Cloudiness v Latitude in the Southern Hemisphere
# It does not appear to be a liner relationship and the R-squared value is very low supporting the idea that
# these two variables are not correlated.

# %%
#Northern Hemisphere - Wind Speed (mph) vs. Latitude
## Convert variables
Northern_df['Wind Speed (mph)'] = pd.to_numeric(Northern_df['Wind Speed (mph)'])

#List variables
lat = Northern_df['Latitude']
winds = Northern_df['Wind Speed (mph)']

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(lat, winds)
regress_values = lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(lat,winds)

# Plot regression line
plt.plot(lat,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')

# Print r square value
print(f"R squared: {rvalue**2}")

# Show plot
plt.show()
plt.savefig("../NorthernWindVLatitude.png")
# Out:
# R squared: 0.0056620590517692726
# <ipython-input-29-4b5906e8539f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Northern_df['Wind Speed (mph)'] = pd.to_numeric(Northern_df['Wind Speed (mph)'])

# %% [markdown]
# # Northern Hemisphere Wind Speed v Latitude
# There does not appear to be a linear relationship.

# %%
#Southern Hemisphere - Wind Speed (mph) vs. Latitude
## Convert variables
Southern_df['Wind Speed (mph)'] = pd.to_numeric(Southern_df['Wind Speed (mph)'])

#List variables
lat = Southern_df['Latitude']
winds = Southern_df['Wind Speed (mph)']

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(lat, winds)
regress_values = lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(lat,winds)

# Plot regression line
plt.plot(lat,regress_values,"r-")
plt.annotate(line_eq,(-30,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')

# Print r square value
print(f"R squared: {rvalue**2}")

# Show plot
plt.show()
plt.savefig("../SouthernWindVLatitude.png")
# Out:
# <ipython-input-34-e9659e2190df>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Southern_df['Wind Speed (mph)'] = pd.to_numeric(Southern_df['Wind Speed (mph)'])
# R squared: 0.08298805356574711

# %% [markdown]
# # Southern Hemisphere Wind Speed (mph) v Latitude
# There does not appear to be a relationship. The R-Squared value is very small.
